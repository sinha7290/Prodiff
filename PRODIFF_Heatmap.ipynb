# %%
# IMPORT STATEMENTS
import cv2
import re
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import matplotlib.patches as mpatches
import matplotlib.colors as colors
from matplotlib.transforms import *
import PIL
import math
#get_ipython().magic('matplotlib inline')
from sklearn.decomposition import PCA
#import gseapy as gp
#from gseapy.plot import gseaplot
#gp.__path__
import pandas as pd
from scipy.stats import zscore
import seaborn as sns
import json
from scipy.stats import fisher_exact, ttest_ind
from collections import Counter
from pprint import pprint
import os
import pickle
import sys
sys.path.append("/booleanfs2/sahoo/Hegemon/")
sys.path.append("../")
import StepMiner as smn
import HegemonUtil as hu
acolor = ["#00CC00", "#D8A03D","#EC008C",
          'cyan', "#B741DC", "#808285",
          'blue', 'black', 'green', 'red',
          'orange', 'brown', 'pink', 'purple']

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def getPDF(cfile):
    import bone
    reload(bone)
    from matplotlib.backends.backend_pdf import PdfPages

    pdf = PdfPages(cfile)
    return pdf

def closePDF(pdf):
    import datetime
    d = pdf.infodict()
    d['Title'] = 'Plots'
    d['Author'] = 'Saptarshi'
    d['Subject'] = "heatmap"
    d['Keywords'] = 'heatmap'
    d['CreationDate'] = datetime.datetime(2021, 1, 18)
    d['ModDate'] = datetime.datetime.today()
    pdf.close()
    
cfile = "/Users/sinha7290/public_html/BoNE/heatmaps/HCT116.pdf"
pdf = getPDF(cfile)

df = pd.read_csv('/Users/sinha7290/public_html/BoNE/heatmaps/HCT114.txt', sep='\t')
from scipy.stats import zscore
D1=df.apply(zscore)
fig, ax = plt.subplots(figsize = (5, 4))
#sns.heatmap(data, cmap ='coolwarm', linewidths = 0.10)
#sns.heatmap(data.corr(), annot=True)
#sns.heatmap(DATA,cmap ='coolwarm', annot=False)
Z=zscore(df, axis=0)
#D2=df.apply(zscore, axis=1)
Y=list(df.index)
X=list(df.columns)
sns.heatmap(Z,cmap ='PuOr_r',vmax=2,center=-0.6,vmin=-2, annot=False,xticklabels=X, yticklabels=Y)
#sns.heatmap(Z,cmap ='PuOr', annot=False,xticklabels=X, yticklabels=Y)
#HCT116


pdf.savefig(transparent=True,bbox_inches = 'tight')
closePDF(pdf)

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def getPDF(cfile):
    import bone
    reload(bone)
    from matplotlib.backends.backend_pdf import PdfPages

    pdf = PdfPages(cfile)
    return pdf

def closePDF(pdf):
    import datetime
    d = pdf.infodict()
    d['Title'] = 'Plots'
    d['Author'] = 'Saptarshi'
    d['Subject'] = "heatmap"
    d['Keywords'] = 'heatmap'
    d['CreationDate'] = datetime.datetime(2021, 1, 18)
    d['ModDate'] = datetime.datetime.today()
    pdf.close()
    
cfile = "/Users/sinha7290/public_html/BoNE/heatmaps/SW480.pdf"
pdf = getPDF(cfile)

df = pd.read_csv('/Users/sinha7290/public_html/BoNE/heatmaps/SW480.txt', sep='\t')
from scipy.stats import zscore
D1=df.apply(zscore)
fig, ax = plt.subplots(figsize = (5, 4))
#sns.heatmap(data, cmap ='coolwarm', linewidths = 0.10)
#sns.heatmap(data.corr(), annot=True)
#sns.heatmap(DATA,cmap ='coolwarm', annot=False)
Z=zscore(df, axis=0)
#D2=df.apply(zscore, axis=1)
Y=list(df.index)
X=list(df.columns)
sns.heatmap(Z,cmap ='PuOr_r',vmax=2,center=-0.6,vmin=-2, annot=False,xticklabels=X, yticklabels=Y)
#sns.heatmap(Z,cmap ='PuOr', annot=False,xticklabels=X, yticklabels=Y)
#HCT116


pdf.savefig(transparent=True,bbox_inches = 'tight')
closePDF(pdf)

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def getPDF(cfile):
    import bone
    reload(bone)
    from matplotlib.backends.backend_pdf import PdfPages

    pdf = PdfPages(cfile)
    return pdf

def closePDF(pdf):
    import datetime
    d = pdf.infodict()
    d['Title'] = 'Plots'
    d['Author'] = 'Saptarshi'
    d['Subject'] = "heatmap"
    d['Keywords'] = 'heatmap'
    d['CreationDate'] = datetime.datetime(2021, 1, 18)
    d['ModDate'] = datetime.datetime.today()
    pdf.close()
    
cfile = "/Users/sinha7290/public_html/BoNE/heatmaps/invivo.pdf"
pdf = getPDF(cfile)
df = pd.read_csv('/Users/sinha7290/public_html/BoNE/heatmaps/invivo.txt', sep='\t')
from scipy.stats import zscore
D1=df.apply(zscore)
fig, ax = plt.subplots(figsize = (5, 4))
#sns.heatmap(data, cmap ='coolwarm', linewidths = 0.10)
#sns.heatmap(data.corr(), annot=True)
#sns.heatmap(DATA,cmap ='coolwarm', annot=False)
Z=zscore(df, axis=0)
#D2=df.apply(zscore, axis=1)
Y=list(df.index)
X=list(df.columns)
sns.heatmap(Z,cmap ='PuOr_r',vmax=2,center=-0.4,vmin=-2, annot=False,xticklabels=X, yticklabels=Y)
#sns.heatmap(Z,cmap ='PuOr', annot=False,xticklabels=X, yticklabels=Y)
#invivo

pdf.savefig(transparent=True,bbox_inches = 'tight')
closePDF(pdf)

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def getPDF(cfile):
    import bone
    reload(bone)
    from matplotlib.backends.backend_pdf import PdfPages

    pdf = PdfPages(cfile)
    return pdf

def closePDF(pdf):
    import datetime
    d = pdf.infodict()
    d['Title'] = 'Plots'
    d['Author'] = 'Saptarshi'
    d['Subject'] = "heatmap"
    d['Keywords'] = 'heatmap'
    d['CreationDate'] = datetime.datetime(2021, 1, 18)
    d['ModDate'] = datetime.datetime.today()
    pdf.close()
    
cfile = "/Users/sinha7290/public_html/BoNE/heatmaps/organoid.pdf"
pdf = getPDF(cfile)

df = pd.read_csv('/Users/sinha7290/public_html/BoNE/heatmaps/organoid.txt', sep='\t')
from scipy.stats import zscore
D1=df.apply(zscore)
fig, ax = plt.subplots(figsize = (5, 10))
#sns.heatmap(data, cmap ='coolwarm', linewidths = 0.10)
#sns.heatmap(data.corr(), annot=True)
#sns.heatmap(DATA,cmap ='coolwarm', annot=False)
Z=zscore(df, axis=0)
#D2=df.apply(zscore, axis=1)
Y=list(df.index)
X=list(df.columns)
sns.heatmap(Z,cmap ='PuOr_r',vmax=2,center=-0.5,vmin=-2, annot=False,xticklabels=X, yticklabels=Y)
#sns.heatmap(Z,cmap ='PuOr', annot=False,xticklabels=X, yticklabels=Y)
#organoid

pdf.savefig(transparent=True,bbox_inches = 'tight')
closePDF(pdf)

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def getPDF(cfile):
    import bone
    reload(bone)
    from matplotlib.backends.backend_pdf import PdfPages

    pdf = PdfPages(cfile)
    return pdf

def closePDF(pdf):
    import datetime
    d = pdf.infodict()
    d['Title'] = 'Plots'
    d['Author'] = 'Saptarshi'
    d['Subject'] = "heatmap"
    d['Keywords'] = 'heatmap'
    d['CreationDate'] = datetime.datetime(2021, 1, 18)
    d['ModDate'] = datetime.datetime.today()
    pdf.close()
    
cfile = "/Users/sinha7290/public_html/BoNE/heatmaps/IC50_heatmap.pdf"
pdf = getPDF(cfile)

df = pd.read_csv('/Users/sinha7290/public_html/BoNE/heatmaps/IC50_heatmap.txt', sep='\t')
df=np.log10(df)
D1=df.apply(zscore)
#fig, ax = plt.subplots(figsize = (2, 5))
#sns.heatmap(data, cmap ='coolwarm', linewidths = 0.10)
#sns.heatmap(data.corr(), annot=True)
#sns.heatmap(DATA,cmap ='coolwarm', annot=False)
Z=zscore(df, axis=0)
#D2=df.apply(zscore, axis=1)
Y=list(df.index)
X=list(df.columns)
#sns.heatmap(Z,cmap ='PuOr',vmax=1.5,center=-0.5,vmin=-1.5, annot=False,xticklabels=X, yticklabels=Y)
#sns.heatmap(Z,cmap ='PuOr', annot=False,xticklabels=X, yticklabels=Y)
#sns.clustermap(df,cmap ='PuOr', vmax=0.02,center=0.005,vmin=-0.02,figsize=(3, 6), annot=False, dendrogram_ratio=(.3, .2), col_cluster=False,xticklabels=X, yticklabels=Y)

sns.clustermap(df,cmap ='PuOr_r',figsize=(3, 6), dendrogram_ratio=(.3, .2), col_cluster=False,xticklabels=X, yticklabels=Y)

#SW480

pdf.savefig(transparent=True,bbox_inches = 'tight')
closePDF(pdf)
