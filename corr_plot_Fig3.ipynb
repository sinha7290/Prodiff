# %%
import seaborn as sns 
from matplotlib import pyplot as plt 
import pandas as pd 
from scipy import stats 
import numpy as np
sns.set_style() 
df = pd.read_csv('am_corr.txt',sep='\t')  

df_PRKAB1=df["PRKAB1"]
df_CDX2=df["CDX2"]
df_IC50=np.log10(df["IC50"])
#df_IC50=df["IC50"]
df_G=df["Group"]
df0=pd.concat([df_PRKAB1, df_CDX2, df_IC50, df_G], axis=1)

#sns.lmplot(x='CDX2',y='IC50',data=df)
sns.lmplot(x='CDX2',y='IC50',data=df,hue='Group',markers=['o','x'],palette=dict(H="b", NH="r"))

#slope, intercept, r_value, p_value, std_err = stats.linregress(df['CDX2'],df['IC50'])  
#ax = sns.regplot(x="CDX2", y="IC50", data=df, line_kws={'label':"y={0:.2f}x+{1:.2f},r : {2:.2f},p : {3:.3e}".format(slope,intercept,r_value,p_value)})  
#ax.legend() 
plt.show()

# %%
# IMPORT STATEMENTS
import cv2
import re
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import matplotlib.patches as mpatches
import matplotlib.colors as colors
from matplotlib.transforms import *
import PIL
import math
#get_ipython().magic('matplotlib inline')
from sklearn.decomposition import PCA
import gseapy as gp
from gseapy.plot import gseaplot
gp.__path__
import pandas as pd
from scipy.stats import zscore
import seaborn as sns
import json
from scipy.stats import fisher_exact, ttest_ind
from collections import Counter
from pprint import pprint
import os
import pickle
import sys
sys.path.append("/booleanfs2/sahoo/Hegemon/")
sys.path.append("../")
import StepMiner as smn
import HegemonUtil as hu
acolor = ["#00CC00", "#D8A03D","#EC008C",
          'cyan', "#B741DC", "#808285",
          'blue', 'black', 'green', 'red',
          'orange', 'brown', 'pink', 'purple']

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3

# %%
import seaborn as sns 
from matplotlib import pyplot as plt 
import pandas as pd 
from scipy import stats 
import numpy as np
sns.set_style() 
df = pd.read_csv('am_corr.txt',sep='\t')  

df_PRKAB1=df["PRKAB1"]
df_CDX2=df["CDX2"]
df_IC50=np.log10(df["IC50"])
#df_IC50=df["IC50"]
df_G=df["Group"]
df0=pd.concat([df_PRKAB1, df_CDX2, df_IC50, df_G], axis=1)

#sns.lmplot(x='PRKAB1',y='IC50',data=df)
sns.lmplot(x='PRKAB1',y='IC50',data=df,hue='Group',markers=['o','x'],palette=dict(H="b", NH="r"))

#slope, intercept, r_value, p_value, std_err = stats.linregress(df['PRKAB1'],df['IC50'])  
#ax = sns.regplot(x="PRKAB1", y="IC50", data=df, line_kws={'label':"y={0:.2f}x+{1:.2f},r : {2:.2f},p : {3:.3e}".format(slope,intercept,r_value,p_value)})  
#ax.legend() 
plt.show()

# %%
import seaborn as sns 
from matplotlib import pyplot as plt 
import pandas as pd 
from scipy import stats 
import numpy as np
sns.set_style() 
df = pd.read_csv('am_corr.txt',sep='\t')  

df_IC50=(df["IC50"])
df_CCDC88A=(df["CCDC88A"])
#df_IC50=np.log10(df["IC50"])
#df_IC50=df["IC50"]
#df_G=df["Group"]
#df0=pd.concat([df_PRKAB1, df_CDX2, df_IC50, df_G], axis=1)
df=pd.concat([df_IC50, df_CCDC88A], axis=1)

sns.lmplot(x='IC50',y='CCDC88A',data=df)
#sns.lmplot(x='CDX2',y='PRKAB1',data=df0,hue='Group',markers=['o','x'])

slope, intercept, r_value, p_value, std_err = stats.linregress(df['IC50'],df['CCDC88A'])  
ax = sns.regplot(x="IC50", y="CCDC88A", data=df, line_kws={'label':"y={0:.2f}x+{1:.2f},r : {2:.2f},p : {3:.3e}".format(slope,intercept,r_value,p_value)})  
ax.legend() 
#plt.show()

# %%
# IMPORT STATEMENTS
import cv2
import re
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
import matplotlib.patches as mpatches
import matplotlib.colors as colors
from matplotlib.transforms import *
import PIL
import math
#get_ipython().magic('matplotlib inline')
from sklearn.decomposition import PCA
import gseapy as gp
from gseapy.plot import gseaplot
gp.__path__
import pandas as pd
from scipy.stats import zscore
import seaborn as sns
import json
from scipy.stats import fisher_exact, ttest_ind
from collections import Counter
from pprint import pprint
import os
import pickle
import sys
sys.path.append("/booleanfs2/sahoo/Hegemon/")
sys.path.append("../")
import StepMiner as smn
import HegemonUtil as hu
acolor = ["#00CC00", "#D8A03D","#EC008C",
          'cyan', "#B741DC", "#808285",
          'blue', 'black', 'green', 'red',
          'orange', 'brown', 'pink', 'purple']

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3

# %%
import seaborn as sns 
from matplotlib import pyplot as plt 
import pandas as pd 
from scipy import stats 
import numpy as np
sns.set_style() 
df = pd.read_csv('am_corr2.txt',sep='\t')  

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def getPDF(cfile):
    import bone
    reload(bone)
    from matplotlib.backends.backend_pdf import PdfPages

    pdf = PdfPages(cfile)
    return pdf

def closePDF(pdf):
    import datetime
    d = pdf.infodict()
    d['Title'] = 'Plots'
    d['Author'] = 'Saptarshi'
    d['Subject'] = "heatmap"
    d['Keywords'] = 'heatmap'
    d['CreationDate'] = datetime.datetime(2021, 1, 18)
    d['ModDate'] = datetime.datetime.today()
    pdf.close()

cfile = "/Users/sinha7290/public_html/BoNE/CDX2_correlation_IC50.pdf"
pdf = getPDF(cfile)    
#fig, ax = plt.subplots(figsize = (5, 5))


df_X=df["X"]
df_Y=df["Y"]
#df_CCDC88A=df["CCDC88A"]
#df_IC50=np.log10(df["IC50"])
#df_IC50=df["IC50"]
df_G=df["Group"]
df0=pd.concat([df_X, df_Y, df_G], axis=1)
g=sns.lmplot(x='X',y='Y',data=df0,hue='Group',markers=['o','x','+'],palette=dict(PRKAB1="b", CDX2="r",CCDC88A='y'))
g.set(ylim=(0, 0.03))
g.set(xlim=(0, None))

#sns.lmplot(x='CCDC88A',y='IC50',data=df)
#sns.lmplot(x='X',y='Y',data=df,hue='Group',markers=['o','x','+'],palette=dict(H="b", NH="r"))

slope, intercept, r_value, p_value, std_err = stats.linregress(df['Y'],df['X'])  
ax = sns.regplot(x="X", y="Y", data=df0, line_kws={'label':"y={0:.2f}x+{1:.2f},r : {2:.2f},p : {3:.3e}".format(slope,intercept,r_value,p_value)})  
ax.legend() 
#plt.show() 
#df0
pdf.savefig(transparent=True,bbox_inches = 'tight')
closePDF(pdf)
